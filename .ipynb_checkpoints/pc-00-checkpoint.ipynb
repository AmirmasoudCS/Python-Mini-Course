# %% [markdown]
# <div>
#     <h1 align="center">Python Fundamentals</h1>
#     <h2 align="center">Session 00 - Introductions</h2>
#     <hr>
#     <h3 align="center">Amirmasoud Mohammadian</h3>
# </div>

# %% [markdown]
# <hr>
# <div>
#     <ol>
#         <b><li>Install Dependencies</li></b>
#             <ul>
#                 <li>Installing VS Code</li>
#                 <li>Installing Extentions</li>
#                 <li>Downloading Python</li>
#                 <li>Mirroring</li>
#                 <li>Documents</li>
#             </ul>
#         <b><li>Variables and Data Type</li></b>
#             <ul>
#                 <li>Variables</li>
#                 <li>Naming Rules</li>
#                 <li>Basic data types</li>
#                 <li>Type conversions</li>
#             </ul>
#         <b><li>Input and Output</li></b>
#             <ul>
#                 <li>print()</li>
#                 <li>input()</li>
#                 <li>Formatting output</li>
#             </ul>
#         <b><li>Operators</li></b>
#             <ul>
#                 <li>Arithmetic operators (+ - * / % **)</li>
#                 <li>Comparison operators (== != > < >= <=)</li>
#                 <li>Logical Operators (and , or , not)</li>
#             </ul>
#         <b><li>Conditional Statements</li></b>
#             <ul>
#                 <li>if</li>
#                 <li>elif</li>
#                 <li>else</li>
#             </ul>
#         <b><li>Loops</li></b>
#             <ul>
#                 <li>for loops</li>
#                 <li>while loops</li>
#                 <li>break</li>
#                 <li>continue</li>
#                 <li>range()</li>
#             </ul>
#         <b><li>Data Structures</li></b>
#             <ul>
#                 <li>Lists</li>
#                 <li>Tuples</li>
#                 <li>Dictionaries</li>
#             </ul>
#         <b><li>Functions</li></b>
#             <ul>
#                 <li>Why functions</li>
#                 <li>Defining functions</li>
#                 <li>Parameters</li>
#                 <li>Return values</li>
#             </ul>
#         <b><li>Modules and Libraries</li></b>
#             <ul>
#                 <li>Importing modules</li>
#                 <li>Using built-in modules</li>
#             </ul>
#         <b><li>Basic File Handling</li></b>
#             <ul>
#                 <li>Reading</li>
#                 <li>Writing</li>
#             </ul>
#     </ol>
# </div>
