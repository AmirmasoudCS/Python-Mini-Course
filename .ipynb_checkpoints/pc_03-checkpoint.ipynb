# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #f3d9ff, #f8cdda);
#     padding: 30px;
#     border-radius:12px;
# ">
#     <h1 align="center">Python Fundamentals</h1>
#     <h2 align="center">Session 03 - Input and Output</h2>
#     <hr>
#     <h3 align="center">Amirmasoud Mohammadian</h3>
# </div>

# %% [markdown]
# <h1>Output</h1>
# <h2>Print()</h2>

# %%
name = "Amirmasoud"
age = 20
print(name)
print(age)
# Out:
# Amirmasoud
# 20

# %%
# print(name"\n"age)

# %% [markdown]
# <h2>String Concatenation</h2>

# %%
first_name = "Ali"
last_name = "Ahmadi"
print(first_name, last_name)
# Out:
# Ali Ahmadi

# %%
first_name, last_name
# Out:
# ('Ali', 'Ahmadi')

# %%
print("Hello I'm " + first_name + " " + last_name)
# Out:
# Hello I'm Ali Ahmadi

# %%
print("Hello I'm " , first_name , " " , last_name)
# Out:
# Hello I'm  Ali   Ahmadi

# %%
age = 25

# %%
print(first_name + last_name)
print(first_name, last_name)
# Out:
# AliAhmadi
# Ali Ahmadi

# %%
# print(first_name, last_name, age)

# %%
# print(first_name + last_name + age)

# %% [markdown]
# <h2>Formatted Strings</h2>
# <div><p>f-strings</p></div>

# %%
first_name = "Harry"
last_name = "Potter"
age = 14 # During Goblet of Fire

# %%
print(f"Hello I'm {first_name} {last_name} and I'm {age}")
# Out:
# Hello I'm Harry Potter and I'm 14

# %% [markdown]
# <h2>Special Parameters</h2>

# %% [markdown]
# <div>
#     <ul>
#         <li> sep</li>
#         <li> end</li>
#     </ul>
# </div>

# %%
year = 2026
month = 5
day = 6
# Goal = 2026-5-6

# %%
print("Hello")
print("World!")
# Out:
# Hello
# World!

# %% [markdown]
# <h1>Getting Input</h1>
# <h2>Input()</h2>

# %%
# Get users name

# %%
print("Please enter your name")
name = input()
# Out:
# Please enter your name
#  Amirmasoud

# %%
name
# Out:
# 'Amirmasoud'

# %%
username = input("Please enter your name.")
# Out:
# Please enter your name. Amirmasoud

# %%
username
# Out:
# 'Amirmasoud'

# %%
born_year = input("Which year were you born in?")
# Out:
# Which year were you born in? 2006

# %%
# print("Age:", 2026 - born_year)

# %%
product_price = input("Enter product price.")
product_qty = input("Enter product quantity.")
# Out:
# Enter product price. 10000
# Enter product quantity. 20

# %%
# print("Total:", product_price * product_qty)
